# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
# Load the dataset
DATA_PATH = '../data-preprocessing/VinhLong_data.csv'
data = pd.read_csv(DATA_PATH)
data = data[data['Nhiệt độ'] <= 60]

# %%
data['Ngày'] = pd.to_datetime(data['Ngày'], format='%d/%m/%Y')
data['Giờ'] = pd.to_datetime(data['Giờ'], format='%H:%M').dt.time
data['Datetime'] = pd.to_datetime(data['Ngày'].astype(str) + ' ' + data['Giờ'].astype(str))
data.set_index('Datetime', inplace=True)
data.drop(['Ngày', 'Giờ'], axis=1, inplace=True)
data.head()
# Out:
#                      Nhiệt độ Độ ẩm  Khí áp T.độ gió H. gió
# Datetime
# 2014-01-01 01:00:00      22.2    89  1013.7      1.3    225
# 2014-01-01 02:00:00      21.8    90  1012.9        1    270
# 2014-01-01 03:00:00      22.8    80  1012.5      3.1    320
# 2014-01-01 04:00:00      22.7    80  1012.5      1.2    235
# 2014-01-01 05:00:00      22.0    84  1012.5      3.7    319

# %%
data.replace(['-', ''], np.nan, inplace=True)
data.dropna(inplace=True)
data = data.apply(pd.to_numeric, errors='ignore')
data.tail()
# Out:
#                      Nhiệt độ  Độ ẩm  Khí áp  T.độ gió  H. gió
# Datetime
# 2024-01-15 19:00:00      28.3     65  1011.8       2.2     154
# 2024-01-15 20:00:00      27.4     70  1012.1       2.1     152
# 2024-01-15 21:00:00      27.0     72  1012.5       0.2     149
# 2024-01-15 22:00:00      26.5     75  1012.2       1.3     153
# 2024-02-21 07:00:00      24.4     97  1012.6       1.4     142

# %%
print(data.isna().sum())
# Out:
# Nhiệt độ    0
# Độ ẩm       0
# Khí áp      0
# T.độ gió    0
# H. gió      0
# dtype: int64

# %%
hourly_data = data.resample('H').mean()
hourly_data.replace(['-', ''], np.nan, inplace=True)
hourly_data.dropna(inplace=True)
hourly_data = hourly_data.apply(pd.to_numeric, errors='ignore')
hourly_data.tail()
# Out:
#                      Nhiệt độ  Độ ẩm  Khí áp  T.độ gió  H. gió
# Datetime
# 2024-01-15 19:00:00      28.3   65.0  1011.8       2.2   154.0
# 2024-01-15 20:00:00      27.4   70.0  1012.1       2.1   152.0
# 2024-01-15 21:00:00      27.0   72.0  1012.5       0.2   149.0
# 2024-01-15 22:00:00      26.5   75.0  1012.2       1.3   153.0
# 2024-02-21 07:00:00      24.4   97.0  1012.6       1.4   142.0

# %%
hourly_data.reset_index(drop=True, inplace=True)

# %%
hourly_data.head()
# Out:
#    Nhiệt độ  Độ ẩm  Khí áp  T.độ gió  H. gió
# 0      22.2   89.0  1013.7       1.3   225.0
# 1      21.8   90.0  1012.9       1.0   270.0
# 2      22.8   80.0  1012.5       3.1   320.0
# 3      22.7   80.0  1012.5       1.2   235.0
# 4      22.0   84.0  1012.5       3.7   319.0

# %%
print(hourly_data.isna().sum())
# Out:
# Nhiệt độ    0
# Độ ẩm       0
# Khí áp      0
# T.độ gió    0
# H. gió      0
# dtype: int64

# %%
# data_length = len(hourly_data)

# train_idx = int(data_length * 0.80)
# test_idx = int(data_length * 0.20)

# train = hourly_data[:train_idx]
# test = hourly_data[train_idx:]

# print(f"Train Shape: {train.shape}")
# print(f"Test Shape: {test.shape}")

# %%
def train_test_split(data, n_test):
    n_test = int(len(data) * 0.20)
    return data[:-n_test], data[-n_test:]

# %%
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

# %%
# testX = test['Nhiệt độ']
# testy = test.drop(columns=['Nhiệt độ'])
# trainX = train['Nhiệt độ']
# trainy = train.drop(columns=['Nhiệt độ'])

# %%
def create_features(data, n_lags=3):
    df = data.copy()
    for n in range(1, n_lags + 1):
        df[f'lag_{n}'] = df['Nhiệt độ'].shift(n)
    # df['rolling_mean_3'] = df['Nhiệt độ'].rolling(window=3).mean()
    # target
    df['target_temp'] = df['Nhiệt độ'].shift(-1)
    df['target_humidity'] = df['Độ ẩm'].shift(-1)
    df['target_baro'] = df['Khí áp'].shift(-1)
    df['target_windspeed'] = df['T.độ gió'].shift(-1)
    df['target_winddirec'] = df['H. gió'].shift(-1)
    df.dropna(inplace=True)
    return df

# Apply feature engineering
hourly_data = create_features(hourly_data, n_lags=3)

# %%
from sklearn.model_selection import GridSearchCV

def xgboost_grid_search(trainX, trainy):
    model = XGBRegressor(objective='reg:squarederror')
    param_grid = {
        'n_estimators': [100, 500, 1000],
        'max_depth': [3, 5, 7, 9],
        'learning_rate': [0.01, 0.05, 0.1]
    }
    grid_search = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=3)
    grid_search.fit(trainX, trainy)
    print("Best parameters found: ", grid_search.best_params_)
    return grid_search.best_estimator_

# %%
from sklearn.multioutput import MultiOutputRegressor

def xgboost_forecast(train, testX):
    train = np.asarray(train)
    trainX, trainy = train[:, :-5], train[:, -5:]
    model = MultiOutputRegressor(xgboost_grid_search(trainX, trainy))
    model.fit(trainX, trainy)
    yhat = model.predict([testX])
    return yhat[0]

# %%
from tqdm import tqdm

# %%
def rolling_forecast(data, window_size, n_test):
    predictions = list()
    train, test = train_test_split(data.values, n_test)
    history = [x for x in train]
    for i in range(len(test)):
        # Define the rolling window for training
        rolling_train = history[-window_size:]
        testX, testy = test[i, :-5], test[i, -5:]
        yhat = xgboost_forecast(rolling_train, testX)
        predictions.append(yhat)
        history.append(test[i])
        print('>expected=%.1f, predicted=%.1f' % (testy[0], yhat[0]))
    predictions = np.array(predictions)
    error = np.sqrt(mean_squared_error(test[:, -5:], predictions, multioutput='raw_values'))
    return error, test[:, -5:], predictions

# %%
hourly_data.head()
# Out:
#    Nhiệt độ  Độ ẩm  Khí áp  T.độ gió  H. gió  lag_1  lag_2  lag_3  \
# 3      22.7   80.0  1012.5       1.2   235.0   22.8   21.8   22.2
# 4      22.0   84.0  1012.5       3.7   319.0   22.7   22.8   21.8
# 5      21.6   85.0  1013.2       2.2   321.0   22.0   22.7   22.8
# 6      21.5   83.0  1014.0       1.7   283.0   21.6   22.0   22.7
# 7      21.8   83.0  1014.7       2.7   303.0   21.5   21.6   22.0
#
#    target_temp  target_humidity  target_baro  target_windspeed  \
# 3         22.0             84.0       1012.5               3.7
# 4         21.6             85.0       1013.2               2.2
# 5         21.5             83.0       1014.0               1.7
# 6         21.8             83.0       1014.7               2.7
# 7         22.7             80.0       1014.9               2.1
#
#    target_winddirec
# 3             319.0
# 4             321.0
# 5             283.0
# 6             303.0
# 7             299.0

# %%
print(hourly_data.isna().sum())
# Out:
# Nhiệt độ            0
# Độ ẩm               0
# Khí áp              0
# T.độ gió            0
# H. gió              0
# lag_1               0
# lag_2               0
# lag_3               0
# target_temp         0
# target_humidity     0
# target_baro         0
# target_windspeed    0
# target_winddirec    0
# dtype: int64

# %%
from sklearn.metrics import mean_squared_error

window_size = 100

# Evaluate the model
rmse, y, yhat = rolling_forecast(hourly_data, window_size, 12)

# Print RMSE for each target
targets = ['Temperature', 'Humidity', 'Pressure', 'Wind Speed', 'Wind Direction']

for i, target in tqdm(enumerate(targets), total=len(targets)):
    print(f'RMSE for {target}: {rmse[i]:.3f}')
# Out:
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=29.6, predicted=30.7
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=30.2, predicted=28.8
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
# >expected=29.8, predicted=29.1
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}
# >expected=28.7, predicted=29.7
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100}
# >expected=28.0, predicted=30.1
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# >expected=27.2, predicted=27.6
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=26.8, predicted=26.7
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# >expected=26.5, predicted=26.6
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 1000}
# >expected=26.5, predicted=26.5
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=26.4, predicted=26.6
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=26.3, predicted=26.2
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# >expected=25.9, predicted=25.8
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=25.6, predicted=25.8
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=25.8, predicted=25.8
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=25.6, predicted=26.0
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=25.7, predicted=26.4
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=26.6, predicted=26.0
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=28.8, predicted=27.5
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=30.3, predicted=30.0
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 1000}
# >expected=31.2, predicted=30.4
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 500}
# >expected=31.9, predicted=32.8
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=32.5, predicted=32.1
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=33.2, predicted=31.7
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=33.5, predicted=31.8
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# >expected=32.8, predicted=32.1
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# >expected=32.5, predicted=32.3
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=31.1, predicted=31.6
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=29.9, predicted=29.6
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# >expected=28.9, predicted=29.2
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=28.1, predicted=28.0
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=27.4, predicted=27.4
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=26.9, predicted=26.6
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=26.8, predicted=26.7
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# >expected=25.9, predicted=26.6
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# >expected=25.8, predicted=25.7
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
# >expected=27.1, predicted=25.7
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=27.9, predicted=27.9
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=29.4, predicted=28.5
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=31.3, predicted=29.1
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=32.1, predicted=31.8
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=33.5, predicted=32.5
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=33.8, predicted=32.5
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=33.7, predicted=32.8
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=33.5, predicted=32.8
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# >expected=32.8, predicted=32.4
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# >expected=27.4, predicted=32.4
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# >expected=27.2, predicted=26.6
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# >expected=27.1, predicted=26.8
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 100}
# >expected=27.0, predicted=26.8
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 100}
# >expected=26.7, predicted=26.7
# Best parameters found:  {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 100}
# >expected=26.7, predicted=26.4
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 500}
# >expected=26.8, predicted=26.5
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 100}
# >expected=26.2, predicted=26.5
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 100}
# >expected=26.1, predicted=25.9
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 500}
# >expected=29.5, predicted=26.0
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 100}
# >expected=29.9, predicted=30.9
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 1000}
# >expected=30.1, predicted=30.8
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 1000}
# >expected=31.2, predicted=31.0
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 100}
# >expected=33.0, predicted=31.8
# Best parameters found:  {'learning_rate': 0.05, 'max_depth': 9, 'n_estimators': 100}
# >expected=33.2, predicted=33.1
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 9, 'n_estimators': 500}
# >expected=32.9, predicted=32.7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 6
#       3 window_size = 100
#       5 # Evaluate the model
# ----> 6 rmse, y, yhat = rolling_forecast(hourly_data, window_size, 12)
#       8 # Print RMSE for each target
#       9 targets = ['Temperature', 'Humidity', 'Pressure', 'Wind Speed', 'Wind Direction']
#
# Cell In[18], line 9, in rolling_forecast(data, window_size, n_test)
#       7 rolling_train = history[-window_size:]
#       8 testX, testy = test[i, :-5], test[i, -5:]
# ----> 9 yhat = xgboost_forecast(rolling_train, testX)
#      10 predictions.append(yhat)
#      11 history.append(test[i])
#
# Cell In[16], line 6, in xgboost_forecast(train, testX)
#       4 train = np.asarray(train)
#       5 trainX, trainy = train[:, :-5], train[:, -5:]
# ----> 6 model = MultiOutputRegressor(xgboost_grid_search(trainX, trainy))
#       7 model.fit(trainX, trainy)
#       8 yhat = model.predict([testX])
#
# Cell In[15], line 11, in xgboost_grid_search(trainX, trainy)
#       5 param_grid = {
#       6     'n_estimators': [100, 500, 1000],
#       7     'max_depth': [3, 5, 7, 9],
#       8     'learning_rate': [0.01, 0.05, 0.1]
#       9 }
#      10 grid_search = GridSearchCV(model, param_grid, scoring='neg_mean_squared_error', cv=3)
# ---> 11 grid_search.fit(trainX, trainy)
#      12 print("Best parameters found: ", grid_search.best_params_)
#      13 return grid_search.best_estimator_
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1008, in BaseSearchCV.fit(self, X, y, **params)
#    1006 refit_start_time = time.time()
#    1007 if y is not None:
# -> 1008     self.best_estimator_.fit(X, y, **routed_params.estimator.fit)
#    1009 else:
#    1010     self.best_estimator_.fit(X, **routed_params.estimator.fit)
#
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:1090, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1079     obj = None
#    1081 (
#    1082     model,
#    1083     metric,
#    (...)
#    1088     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1089 )
# -> 1090 self._Booster = train(
#    1091     params,
#    1092     train_dmatrix,
#    1093     self.get_num_boosting_rounds(),
#    1094     evals=evals,
#    1095     early_stopping_rounds=early_stopping_rounds,
#    1096     evals_result=evals_result,
#    1097     obj=obj,
#    1098     custom_metric=metric,
#    1099     verbose_eval=verbose,
#    1100     xgb_model=model,
#    1101     callbacks=callbacks,
#    1102 )
#    1104 self._set_evaluation_result(evals_result)
#    1105 return self
#
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/lib/python3.11/site-packages/xgboost/core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(10, 15))
targets = ['Temperature', 'Humidity', 'Pressure', 'Wind Speed', 'Wind Direction']
for i, ax in enumerate(axes):
    ax.plot(y[:, i], label='Expected')
    ax.plot(yhat[:, i], label='Predicted')
    mean_value = np.mean(y[:, i])
    ax.axhline(y=mean_value, color='r', linestyle='--', label='Mean')
    ax.set_title(targets[i])
    ax.legend()

plt.tight_layout()
plt.show()

# %%
# # Function to perform walk-forward validation
# def walk_forward_validation(data, n_test):
#     predictions = list()
#     train, test = train_test_split(data.values, n_test)
#     history = [x for x in train]
#     for i in range(len(test)):
#         testX, testy = test[i, :-1], test[i, -1]
#         yhat = xgboost_forecast(history, testX)
#         predictions.append(yhat)
#         history.append(test[i])
#         print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
#     error = mean_absolute_error(test[:, -1], predictions)
#     return error, test[:, -1], predictions

# # Evaluate the model
# mae, y, yhat = walk_forward_validation(hourly_data, 12)
# print('MAE: %.3f' % mae)

# # Plot expected vs predicted values
# plt.plot(y, label='Expected')
# plt.plot(yhat, label='Predicted')
# plt.legend()
# plt.show()
